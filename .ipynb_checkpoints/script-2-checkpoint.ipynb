# %% [markdown]
# # Well Multiphase Production Performance Prediction Using Deep Learning

# %% [markdown]
# ## Libraries Loading

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Activation,GRU
from sklearn.metrics import mean_squared_error
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ##  Data loading and preparation

# %%
data =pd.read_excel('data_well_f15.xlsx', sheet_name= 'Sheet1')

# %%
data.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0 2014-01-16        15/9-F-15 D           24.0             241.770858
# 1 2014-01-17        15/9-F-15 D           24.0             213.851844
# 2 2014-01-18        15/9-F-15 D           24.0             206.614838
# 3 2014-01-19        15/9-F-15 D           24.0             203.074779
# 4 2014-01-20        15/9-F-15 D           24.0             203.980613
#
#    AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# 0                104.898944     185.900111          19.057130
# 1                106.292729     162.213858          19.866146
# 2                106.375279     157.925701          27.814960
# 3                106.392210     156.509777          25.723065
# 4                106.316921     157.110392          12.026200
#
#    AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# 0          8.660590  55.870746  16.900088      27.966259        351.05
# 1          9.470373  51.637986  22.362967      22.346976        485.34
# 2          9.687738  48.689137  22.230421      19.858915        513.12
# 3          9.730942  46.565003  20.959422      18.043991        497.55
# 4          9.401242  46.870221  21.193559      18.355370        469.59
#
#    BORE_GAS_VOL  BORE_WAT_VOL  OIL_RATE  GAS_RATE  WAT_RATE  WAT_CUT  TIME
# 0      52394.90           0.0    351.05  52394.90       0.0      0.0     0
# 1      72058.82           0.0    485.34  72058.82       0.0      0.0     1
# 2      77600.88           0.0    513.12  77600.88       0.0      0.0     2
# 3      72928.16           0.0    497.55  72928.16       0.0      0.0     3
# 4      67199.15           0.0    469.59  67199.15       0.0      0.0     4

# %% [markdown]
# * We remove DATEPRD and NPD_WELL_BORE_NAME variables
# * We remoev also BORE_OIL_VOL, BORE_GAS_VOL, BORE_WAT_VOL since they are used to compute the target variables

# %%
Data = data.drop(['ON_STREAM_HRS','DATEPRD', 'NPD_WELL_BORE_NAME','BORE_OIL_VOL','BORE_GAS_VOL','BORE_WAT_VOL'], axis = 'columns', inplace = False)

# %% [markdown]
# ### Features selection
#
# The correlation describes the strength of the linear association between two variables. It summarizes the strength and direction of the linear (straight-line) association between two quantitative variables.
#
# #### Target variables associations:
#     Based on the correlation matrix:
#     - we can notice that 'GAS_RATE' and 'OIL_RATE' variabales are highly correlated; their correlation estimated by 0.97.
#     - 'WAT_RATE' is slightly negatively correlated with the GAS and OIL rates variables.

# %%
corr = Data.corr()
#corr_data = pd.DataFrame(corr)
sns.heatmap(corr)
corr
# Out:
#                           AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  \
# AVG_DOWNHOLE_PRESSURE                  1.000000                 -0.503128
# AVG_DOWNHOLE_TEMPERATURE              -0.503128                  1.000000
# AVG_DP_TUBING                          0.704743                 -0.264557
# AVG_ANNULUS_PRESS                     -0.141222                  0.486376
# AVG_CHOKE_SIZE_P                       0.035314                  0.219402
# AVG_WHP_P                              0.220187                 -0.234552
# AVG_WHT_P                              0.222522                  0.280442
# DP_CHOKE_SIZE                          0.351619                 -0.297177
# OIL_RATE                               0.085378                  0.101191
# GAS_RATE                               0.118262                  0.086351
# WAT_RATE                               0.469424                 -0.011837
# WAT_CUT                                0.466517                 -0.092183
# TIME                                   0.405122                 -0.128685
#
#                           AVG_DP_TUBING  AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  \
# AVG_DOWNHOLE_PRESSURE          0.704743          -0.141222          0.035314
# AVG_DOWNHOLE_TEMPERATURE      -0.264557           0.486376          0.219402
# AVG_DP_TUBING                  1.000000          -0.043156          0.509808
# AVG_ANNULUS_PRESS             -0.043156           1.000000          0.249963
# AVG_CHOKE_SIZE_P               0.509808           0.249963          1.000000
# AVG_WHP_P                     -0.536875          -0.108599         -0.658955
# AVG_WHT_P                      0.594808           0.403319          0.612635
# DP_CHOKE_SIZE                 -0.334370           0.044007         -0.509366
# OIL_RATE                      -0.266600           0.136947         -0.203958
# GAS_RATE                      -0.208377           0.143196         -0.168396
# WAT_RATE                       0.849282           0.242055          0.651588
# WAT_CUT                        0.890953           0.158517          0.649191
# TIME                           0.892046           0.013281          0.619684
#
#                           AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  OIL_RATE  \
# AVG_DOWNHOLE_PRESSURE      0.220187   0.222522       0.351619  0.085378
# AVG_DOWNHOLE_TEMPERATURE  -0.234552   0.280442      -0.297177  0.101191
# AVG_DP_TUBING             -0.536875   0.594808      -0.334370 -0.266600
# AVG_ANNULUS_PRESS         -0.108599   0.403319       0.044007  0.136947
# AVG_CHOKE_SIZE_P          -0.658955   0.612635      -0.509366 -0.203958
# AVG_WHP_P                  1.000000  -0.553203       0.877865  0.468083
# AVG_WHT_P                 -0.553203   1.000000      -0.302589 -0.022146
# DP_CHOKE_SIZE              0.877865  -0.302589       1.000000  0.469260
# OIL_RATE                   0.468083  -0.022146       0.469260  1.000000
# GAS_RATE                   0.427135   0.026866       0.450399  0.975551
# WAT_RATE                  -0.609480   0.799656      -0.326353 -0.084474
# WAT_CUT                   -0.670468   0.770022      -0.375803 -0.213879
# TIME                      -0.744742   0.650635      -0.535464 -0.456314
#
#                           GAS_RATE  WAT_RATE   WAT_CUT      TIME
# AVG_DOWNHOLE_PRESSURE     0.118262  0.469424  0.466517  0.405122
# AVG_DOWNHOLE_TEMPERATURE  0.086351 -0.011837 -0.092183 -0.128685
# AVG_DP_TUBING            -0.208377  0.849282  0.890953  0.892046
# AVG_ANNULUS_PRESS         0.143196  0.242055  0.158517  0.013281
# AVG_CHOKE_SIZE_P         -0.168396  0.651588  0.649191  0.619684
# AVG_WHP_P                 0.427135 -0.609480 -0.670468 -0.744742
# AVG_WHT_P                 0.026866  0.799656  0.770022  0.650635
# DP_CHOKE_SIZE             0.450399 -0.326353 -0.375803 -0.535464
# OIL_RATE                  0.975551 -0.084474 -0.213879 -0.456314
# GAS_RATE                  1.000000 -0.024832 -0.151671 -0.395560
# WAT_RATE                 -0.024832  1.000000  0.967732  0.846139
# WAT_CUT                  -0.151671  0.967732  1.000000  0.906887
# TIME                     -0.395560  0.846139  0.906887  1.000000

# %% [markdown]
# * We can see the linear relationship between the OIL and GAS rates using the scatter plot.

# %%
plt.scatter(Data['OIL_RATE'], Data['GAS_RATE'])
plt.title('Relationship between Oil and Gas rates')
plt.xlabel('Oil rate')
plt.ylabel('Gas rate')
# Out:
# Text(0, 0.5, 'Gas rate')

# %% [markdown]
# * They even share the same distribution, normal distribution with some outliers in the same levels.
# We can conclude that the prediction of one variable implies the other.

# %%
plt.subplot(1, 2, 1)
sns.boxplot( data=Data, order= ['GAS_RATE'])

plt.subplot(1, 2, 2)
sns.boxplot( data=Data, order= ['OIL_RATE'])

# %% [markdown]
# #### Predictors relationship with the target variables:
#
# * In order to avoid multicollinearity, we compare the correlation between features and remove one of two features that have a correlation higher than 0.9

# %%
datafeatures = Data.drop(['OIL_RATE', 'GAS_RATE', 'WAT_RATE'], axis = 'columns', inplace = False)
corr = datafeatures.corr()
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False
print(columns)
selected_columns = datafeatures.columns[columns]
newdata = datafeatures[selected_columns]
newdata['Time'] = Data['TIME']
newdata['OIL_RATE'] = Data['OIL_RATE'] 
newdata['GAS_RATE'] = Data['GAS_RATE'] 
newdata['WAT_RATE'] = Data['WAT_RATE']
# Out:
# [ True  True  True  True  True  True  True  True  True False]

# %%
newdata.shape
# Out:
# (769, 13)

# %% [markdown]
# ### Data Structure:
# * We prepare the data so it can be fed into the neural network models. We'll check first the dimension of the features and targets data.

# %%
newdata.head()
newdata = newdata.dropna()
newdata.shape
# Out:
# (767, 13)

# %%
X = newdata.iloc[:,:-3].values
print('the features data X is of dimension', X.shape)
Y = newdata.iloc[:,-3:].values
print('the targets data Y is of dimension', Y.shape)
# Out:
# the features data X is of dimension (767, 10)
# the targets data Y is of dimension (767, 3)

# %%
newdata.iloc[:,:-3]
# Out:
#      AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0               241.770858                104.898944     185.900111
# 1               213.851844                106.292729     162.213858
# 2               206.614838                106.375279     157.925701
# 3               203.074779                106.392210     156.509777
# 4               203.980613                106.316921     157.110392
# ..                     ...                       ...            ...
# 764             194.983953                106.517574     179.170590
# 765             194.977634                106.515586     179.204392
# 766             194.317112                106.521356     178.615149
# 767             195.207173                106.506781     179.598751
# 768             195.305708                106.507232     179.547756
#
#      AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  \
# 0            19.057130          8.660590  55.870746  16.900088      27.966259
# 1            19.866146          9.470373  51.637986  22.362967      22.346976
# 2            27.814960          9.687738  48.689137  22.230421      19.858915
# 3            25.723065          9.730942  46.565003  20.959422      18.043991
# 4            12.026200          9.401242  46.870221  21.193559      18.355370
# ..                 ...               ...        ...        ...            ...
# 764          21.318431         31.575767  15.813363  49.020020       1.259761
# 765          21.105330         31.540612  15.773242  48.988494       1.198993
# 766          21.353661         31.522096  15.701963  50.103416       1.279639
# 767          20.629658         31.523457  15.608422  49.841092       1.204128
# 768          20.404848         24.922565  15.757952  48.734245       1.302808
#
#       WAT_CUT  Time
# 0    0.000000     0
# 1    0.000000     1
# 2    0.000000     2
# 3    0.000000     3
# 4    0.000000     4
# ..        ...   ...
# 764  0.586107   898
# 765  0.582881   899
# 766  0.588147   900
# 767  0.583953   901
# 768  0.594275   902
#
# [767 rows x 10 columns]

# %% [markdown]
# * The LSTM model input dimension requires the third dimension that will be the number of the single input row. We'll reshape the X data

# %%
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# * Then we will define the input and output data dimensions from X and Y data.

# %%
input_dimension  = (X.shape[1], X.shape[2])
output_dimension = Y.shape[1]

# %% [markdown]
# * We can split the data into the train, test and validation parts; 70% of the data for training set and the remaining 30% for the testing and validation sets.

# %%
X, Xtest, Y, Ytest = train_test_split(X,Y,test_size=0.15,train_size=0.85)
Xtrain, Xval, Ytrain, Yval = train_test_split(X,Y,test_size = 0.15,train_size =0.7)

# %% [markdown]
# ## Modeling
#
# * We will build two neural networks architectures to predict the triplet (OIL_RATE, GAS_RATE, WAT_RATE).
#
#
# #### 1. LSTM Model:
#
# * We will start by defining the sequential model. The sequential model contains LSTM layers with ReLU activations, Dense output layer,  and Adam optimizer with MSE loss function. We will set the input dimension in the first layer and output dimension in the last layer of the model.
# * Then, we will fit the model with train data.

# %%
from keras import optimizers

#optimizer = optimizers.Adam(clipvalue=1.e-10)

model = Sequential()
model.add(LSTM(64, input_shape=input_dimension, activation="relu"))
model.add(Dense(output_dimension))
model.compile(loss="mse", optimizer="adam") 
#model.compile(loss="mse", optimizer=optimizer) 
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 64)                16896
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 17,091
# Trainable params: 17,091
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Testing Overfitting and Underfitting:
# * To test if our model overfitting or underfitted on the data sample, we use the traning and validation sets
# * Based on the loss function plot of  training and validation sets, we can notice that the loss decreases until the 60th epoch

# %%
history = model.fit(Xtrain, Ytrain, epochs=100,batch_size=5, validation_data=(Xval, Yval), verbose=1)
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('Model Train vs Validation Loss')
pyplot.ylabel('Loss')
pyplot.xlabel('Epoch')
pyplot.legend(['Train', 'Validation'], loc='upper right')
pyplot.show()
# Out:
# Epoch 1/100
# 91/91 [==============================] - 1s 11ms/step - loss: 181634624.0000 - val_loss: 36112644.0000
# Epoch 2/100
# 91/91 [==============================] - 1s 8ms/step - loss: 36678840.0000 - val_loss: 36380556.0000
# Epoch 3/100
# 91/91 [==============================] - 1s 14ms/step - loss: 34075304.0000 - val_loss: 36763616.0000
# Epoch 4/100
# 91/91 [==============================] - 1s 15ms/step - loss: 39263872.0000 - val_loss: 36800628.0000
# Epoch 5/100
# 91/91 [==============================] - 1s 14ms/step - loss: 36056092.0000 - val_loss: 38015368.0000
# Epoch 6/100
# 91/91 [==============================] - 1s 14ms/step - loss: 33857892.0000 - val_loss: 35441880.0000
# Epoch 7/100
# 91/91 [==============================] - 1s 14ms/step - loss: 35858220.0000 - val_loss: 35082240.0000
# Epoch 8/100
# 91/91 [==============================] - 1s 12ms/step - loss: 34966052.0000 - val_loss: 35004012.0000
# Epoch 9/100
# 91/91 [==============================] - 1s 10ms/step - loss: 34972956.0000 - val_loss: 35179452.0000
# Epoch 10/100
# 91/91 [==============================] - 1s 16ms/step - loss: 35469104.0000 - val_loss: 34820768.0000
# Epoch 11/100
# 91/91 [==============================] - 1s 14ms/step - loss: 33273118.0000 - val_loss: 33698232.0000
# Epoch 12/100
# 91/91 [==============================] - 1s 16ms/step - loss: 35195876.0000 - val_loss: 34116612.0000
# Epoch 13/100
# 91/91 [==============================] - 1s 8ms/step - loss: 32331832.0000 - val_loss: 57925696.0000
# Epoch 14/100
# 91/91 [==============================] - 1s 10ms/step - loss: 35993152.0000 - val_loss: 37415252.0000
# Epoch 15/100
# 91/91 [==============================] - 1s 12ms/step - loss: 33421128.0000 - val_loss: 33891752.0000
# Epoch 16/100
# 91/91 [==============================] - 1s 8ms/step - loss: 34062204.0000 - val_loss: 33455508.0000
# Epoch 17/100
# 91/91 [==============================] - 1s 14ms/step - loss: 31701008.0000 - val_loss: 31780866.0000
# 91/91 [==============================] - 1s 13ms/step - loss: 28459432.0000
# Epoch 34/60
# 91/91 [==============================] - 1s 13ms/step - loss: 31970228.0000
# Epoch 35/60
# 91/91 [==============================] - 1s 8ms/step - loss: 32579888.0000
# Epoch 36/60
# 91/91 [==============================] - 1s 11ms/step - loss: 29209248.0000
# Epoch 37/60
# 91/91 [==============================] - 1s 14ms/step - loss: 31157650.0000
# Epoch 38/60
# 91/91 [==============================] - 1s 14ms/step - loss: 27700684.0000
# Epoch 39/60
# 91/91 [==============================] - 1s 14ms/step - loss: 28207676.0000
# Epoch 40/60
# 91/91 [==============================] - 1s 13ms/step - loss: 30545326.0000
# Epoch 41/60
# 91/91 [==============================] - 1s 7ms/step - loss: 32791216.0000
# Epoch 42/60
# 91/91 [==============================] - 1s 9ms/step - loss: 31253338.0000
# Epoch 43/60
# 91/91 [==============================] - ETA: 0s - loss: 31067092.00 - 1s 11ms/step - loss: 30867610.0000
# Epoch 44/60
# 91/91 [==============================] - 1s 9ms/step - loss: 27723626.0000
# Epoch 45/60
# 91/91 [==============================] - 1s 10ms/step - loss: 28322002.0000
# Epoch 46/60
# 91/91 [==============================] - 1s 9ms/step - loss: 26805884.0000
# Epoch 47/60
# 91/91 [==============================] - 1s 14ms/step - loss: 29889342.0000
# Epoch 48/60
# 91/91 [==============================] - 1s 7ms/step - loss: 30885572.0000
# Epoch 49/60
# 91/91 [==============================] - 1s 7ms/step - loss: 28399352.0000
# Epoch 50/60
# 91/91 [==============================] - 1s 11ms/step - loss: 26488178.0000
# Epoch 51/60
# 91/91 [==============================] - 1s 12ms/step - loss: 29732174.0000
# Epoch 52/60
# 91/91 [==============================] - 1s 11ms/step - loss: 27203230.0000 0s -
# Epoch 53/60
# 91/91 [==============================] - 1s 12ms/step - loss: 31311686.0000
# Epoch 54/60
# 91/91 [==============================] - 1s 13ms/step - loss: 30085264.0000
# Epoch 55/60
# 91/91 [==============================] - 1s 13ms/step - loss: 30083544.0000
# Epoch 56/60
# 91/91 [==============================] - 1s 9ms/step - loss: 31188348.0000
# Epoch 57/60
# 91/91 [==============================] - 1s 9ms/step - loss: 27537728.0000
# Epoch 58/60
# 91/91 [==============================] - 1s 10ms/step - loss: 26128512.0000 0s - loss: 2
# Epoch 59/60
# 91/91 [==============================] - 1s 7ms/step - loss: 25149190.0000
# Epoch 60/60
# 91/91 [==============================] - 1s 7ms/step - loss: 26246196.0000

# %% [markdown]
# #### Results prediction and visualization :
#
# * We will predict test data and we check the mean squared error (MSE), the relative squared error (RSE) and the relative abolute error (RAE).

# %%
Predictions = model.predict(Xtest)

# %% [markdown]
# * We plot the result of predictions in the following graph:

# %%
axis = range(len(Xtest))
plt.subplot(1, 1, 1)
plt.title("LSTM Multi-Output Prediction: OIL, GAS and WAT Rates")
plt.scatter(axis, Ytest[:,1],  s=6, label="GAS_RATE test")
plt.plot(axis, Predictions[:,1], label="GAS_RATE pred")

plt.legend()
plt.show()

plt.subplot(2, 1, 1)
plt.scatter(axis, Ytest[:,0],  s=6, label="OIL_RATE test")
plt.plot(axis, Predictions[:,0], label="OIL_RATE pred")

plt.legend()
plt.tight_layout()

plt.show()

plt.subplot(3, 1, 1)
plt.scatter(axis, Ytest[:,2],  s=6, label="WAT_RATE test")
plt.plot(axis, Predictions[:,2], label="WAT_RATE pred")

plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Relative absolute error metric

# %%
def rae(actual: np.ndarray, predicted: np.ndarray):
    """ Relative Absolute Error """
    return np.sum(np.abs(actual - predicted)) / np.sum(np.abs(actual - np.mean(actual)))

def rse(actual, predicted):
    """ Relative Squared Error """
    return np.sum((predicted - actual)**2) / np.sum((actual - np.mean(actual))**2)

print("Relative Absolute Error metric using LSTM model")

print("OIL_RATE RAE:%.4f" % rae(Ytest[:,0], Predictions[:,0]))
print("GAS_RATE RAE:%.4f" % rae(Ytest[:,1], Predictions[:,1])) 
print("WAT_RATE RAE:%.4f" % rae(Ytest[:,2], Predictions[:,2]))

print('\n')
print("Relative Squared Error metric using LSTM model")

print("OIL_RATE RSE:%.4f" % rse(Ytest[:,0], Predictions[:,0]))
print("GAS_RATE RSE:%.4f" % rse(Ytest[:,1], Predictions[:,1])) 
print("WAT_RATE RSE:%.4f" % rse(Ytest[:,2], Predictions[:,2]))
# Out:
# Relative Absolute Error metric using LSTM model
# OIL_RATE RAE:1.1218
# GAS_RATE RAE:0.7698
# WAT_RATE RAE:0.6651
#
#
# Relative Squared Error metric using LSTM model
# OIL_RATE RSE:1.0526
# GAS_RATE RSE:0.7218
# WAT_RATE RSE:0.5293

# %% [markdown]
# #### 2. GRU Model
# * We apply MinMaxSclaer on the data so the high values would not take more attention than the others.
# * Based on the history plot, we set the epoch parameter to 35

# %%
scaleddata = newdata.iloc[:,:-3].values

scaler_x = MinMaxScaler()
scaler_y= MinMaxScaler()

x = scaler_x.fit_transform(newdata.iloc[:,:-3].values)
y = scaler_y.fit_transform(newdata.iloc[:,-3:].values)
x = x.reshape(x.shape[0], x.shape[1], 1)

X, Xtest, Y, Ytest = train_test_split(x,y,test_size=0.15,train_size=0.85)
Xtrain, Xval, Ytrain, Yval = train_test_split(X,Y,test_size = 0.15,train_size =0.7)

model = Sequential()
model.add(GRU(units=50, input_shape=Xtrain.shape[1:], return_sequences=False))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(output_dimension))
model.add(Activation('linear'))
model.compile(loss='mse', optimizer='adam')
history = model.fit(Xtrain, Ytrain, batch_size=5, validation_data=(Xval, Yval), epochs=100)
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('Model Train vs Validation Loss')
pyplot.ylabel('Loss')
pyplot.xlabel('Epoch')
pyplot.legend(['Train', 'Validation'], loc='upper right')
pyplot.show()
# Out:
# Epoch 1/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0285 - val_loss: 0.0139
# Epoch 2/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 3/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0099 - val_loss: 0.0077
# Epoch 4/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0088 - val_loss: 0.0073
# Epoch 5/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0080 - val_loss: 0.0063
# Epoch 6/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0078 - val_loss: 0.0068
# Epoch 7/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 8/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0065 - val_loss: 0.0061
# Epoch 9/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0066 - val_loss: 0.0057
# Epoch 10/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 11/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 12/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 13/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 14/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 15/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0055 - val_loss: 0.0047
# Epoch 16/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 17/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0055 - val_loss: 0.0044
# Epoch 18/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0054 - val_loss: 0.0045
# Epoch 19/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 20/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 21/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 22/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 23/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 24/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 25/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 26/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 27/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0044 - val_loss: 0.0040A: 0s - loss: 0.00
# Epoch 28/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 29/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 30/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0045 - val_loss: 0.0039
# Epoch 31/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 32/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 33/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 34/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 35/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 36/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 37/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 38/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 39/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 40/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 41/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 42/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 43/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0045
# Epoch 44/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0044 - val_loss: 0.0039
# Epoch 45/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 46/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0036 - val_loss: 0.0040ETA: 0s - loss: 0.
# Epoch 47/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 48/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 49/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 50/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 51/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0035 - val_loss: 0.0049
# Epoch 52/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 53/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0034 - val_loss: 0.0052
# Epoch 54/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 55/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 56/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 57/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 58/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 59/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 60/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0041
# Epoch 61/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0032 - val_loss: 0.0047
# Epoch 62/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 63/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0043
# Epoch 64/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0045
# Epoch 65/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 66/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 67/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0051
# Epoch 68/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0045
# Epoch 69/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0053
# Epoch 70/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0035 - val_loss: 0.0047
# Epoch 71/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 72/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0030 - val_loss: 0.0042
# Epoch 73/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 0.0045
# Epoch 74/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0033 - val_loss: 0.0047
# Epoch 75/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0057
# Epoch 76/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0033 - val_loss: 0.0047
# Epoch 77/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0027 - val_loss: 0.0048
# Epoch 78/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0053
# Epoch 79/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0029 - val_loss: 0.0051
# Epoch 80/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0029 - val_loss: 0.0048
# Epoch 81/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 82/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0033 - val_loss: 0.0047
# Epoch 83/100
# 91/91 [==============================] - ETA: 0s - loss: 0.003 - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0051
# Epoch 84/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0030 - val_loss: 0.0055
# Epoch 85/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0051
# Epoch 86/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0031 - val_loss: 0.0049
# Epoch 87/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0029 - val_loss: 0.0056
# Epoch 88/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0031 - val_loss: 0.0050
# Epoch 89/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0030 - val_loss: 0.0053
# Epoch 90/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0049
# Epoch 91/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0048
# Epoch 92/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0029 - val_loss: 0.0047
# Epoch 93/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0049
# Epoch 94/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0051
# Epoch 95/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 96/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0047
# Epoch 97/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 98/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0029 - val_loss: 0.0050
# Epoch 99/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0029 - val_loss: 0.0048
# Epoch 100/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0029 - val_loss: 0.0053

# %%
model = Sequential()
model.add(GRU(units=50, input_shape=Xtrain.shape[1:], return_sequences=False))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(output_dimension))
model.add(Activation('linear'))
model.compile(loss='mse', optimizer='adam')
model.fit(Xtrain, Ytrain, batch_size=5, epochs=35, verbose=0)

predictions = model.predict(Xtest)

# %%
axis = range(len(Xtest))
plt.subplot(1, 1, 1)
plt.title("GRU Multi-Output Prediction: OIL, GAS and WAT Rates")
plt.scatter(axis, Ytest[:,1],  s=6, label="GAS_RATE test")
plt.plot(axis, predictions[:,1], label="GAS_RATE pred")


plt.legend()
plt.show()
plt.subplot(2, 1, 1)
plt.scatter(axis, Ytest[:,0],  s=6, label="OIL_RATE test")
plt.plot(axis, predictions[:,0], label="OIL_RATE pred")
plt.legend()
plt.show()

plt.subplot(3, 1, 1)
plt.scatter(axis, Ytest[:,2],  s=6, label="WAT_RATE test")
plt.plot(axis, predictions[:,2], label="WAT_RATE pred")
plt.legend()
plt.show()

# %%
Predictionsinversed = scaler_y.inverse_transform(predictions)
Ytestinversed = scaler_y.inverse_transform(Ytest)

axis = range(len(Xtest))
plt.subplot(1, 1, 1)
plt.title("GRU Multi-Output Prediction: OIL, GAS and WAT Rates")
plt.scatter(axis, Ytestinversed[:,1],  s=6, label="GAS_RATE test")
plt.plot(axis, Predictionsinversed[:,1], label="GAS_RATE pred")


plt.legend()
plt.show()
plt.subplot(2, 1, 1)
plt.scatter(axis, Ytestinversed[:,0],  s=6, label="OIL_RATE test")
plt.plot(axis, Predictionsinversed[:,0], label="OIL_RATE pred")
plt.legend()
plt.show()

plt.subplot(3, 1, 1)
plt.scatter(axis, Ytestinversed[:,2],  s=6, label="WAT_RATE test")
plt.plot(axis, Predictionsinversed[:,2], label="WAT_RATE pred")
plt.legend()
plt.show()

# %%
print("Relative Absolute Error metric using GRU model")

print("OIL_RATE RAE:%.4f" % rae(Ytestinversed[:,0], Predictionsinversed[:,0]))
print("GAS_RATE RAE:%.4f" % rae(Ytestinversed[:,1], Predictionsinversed[:,1])) 
print("WAT_RATE RAE:%.4f" % rae(Ytestinversed[:,2], Predictionsinversed[:,2]))

print('\n')
print("Relative Squared Error metric using GRU model")

print("OIL_RATE RSE:%.4f" % rse(Ytestinversed[:,0], Predictionsinversed[:,0]))
print("GAS_RATE RSE:%.4f" % rse(Ytestinversed[:,1], Predictionsinversed[:,1])) 
print("WAT_RATE RSE:%.4f" % rse(Ytestinversed[:,2], Predictionsinversed[:,2]))
# Out:
# Relative Absolute Error metric using GRU model
# OIL_RATE RAE:0.4654
# GAS_RATE RAE:0.4729
# WAT_RATE RAE:0.1730
#
#
# Relative Squared Error metric using GRU model
# OIL_RATE RSE:0.2918
# GAS_RATE RSE:0.3242
# WAT_RATE RSE:0.1055

# %% [markdown]
# * After including the scaling processing and building a GRU architecture, we get a high quality predictions with minimal errors. We run the LSTM model on the scaled data to see if we can get accurate results using the LSTM neural network.

# %%
model = Sequential()
model.add(LSTM(64, input_shape=input_dimension, activation="relu"))
model.add(Dense(output_dimension))
model.compile(loss="mse", optimizer="adam") 
model.summary()
history = model.fit(Xtrain, Ytrain, batch_size=5, validation_data=(Xval, Yval), epochs=100)
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('Model Train vs Validation Loss')
pyplot.ylabel('Loss')
pyplot.xlabel('Epoch')
pyplot.legend(['Train', 'Validation'], loc='upper right')
pyplot.show()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 64)                16896
# _________________________________________________________________
# dense_22 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 17,091
# Trainable params: 17,091
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0343 - val_loss: 0.0193
# Epoch 2/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0121 - val_loss: 0.0093
# Epoch 3/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0077 - val_loss: 0.0084
# Epoch 4/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0076 - val_loss: 0.0078
# Epoch 5/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0071 - val_loss: 0.0077
# Epoch 6/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 7/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0062 - val_loss: 0.0065
# Epoch 8/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 9/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 10/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 11/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0058 - val_loss: 0.0075
# Epoch 12/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 13/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 14/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 15/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 16/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 17/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 18/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 19/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 20/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 21/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 22/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 23/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 24/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 25/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 26/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 27/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 28/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0041 - val_loss: 0.0045
# Epoch 29/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 30/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 31/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 32/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 33/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 34/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 35/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 36/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 37/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0038 - val_loss: 0.0043
# Epoch 38/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 39/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 40/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0037 - val_loss: 0.0044
# Epoch 41/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0039 - val_loss: 0.0047
# Epoch 42/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 43/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 44/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 45/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0035 - val_loss: 0.0058
# Epoch 46/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 47/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0034 - val_loss: 0.0057
# Epoch 48/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 49/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 50/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 51/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0035 - val_loss: 0.0050
# Epoch 52/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 53/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 54/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0047
# Epoch 55/100
# 91/91 [==============================] - 1s 7ms/step - loss: 0.0036 - val_loss: 0.0052
# Epoch 56/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 57/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 58/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 59/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0033 - val_loss: 0.0043
# Epoch 60/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0034 - val_loss: 0.0049
# Epoch 61/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 62/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0033 - val_loss: 0.0059
# Epoch 63/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0033 - val_loss: 0.0044
# Epoch 64/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0035 - val_loss: 0.0064
# Epoch 65/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 66/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0031 - val_loss: 0.0046
# Epoch 67/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0032 - val_loss: 0.0041
# Epoch 68/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 69/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0031 - val_loss: 0.0047
# Epoch 70/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0031 - val_loss: 0.0057
# Epoch 71/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0032 - val_loss: 0.0043
# Epoch 72/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0059
# Epoch 73/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0033 - val_loss: 0.0048
# Epoch 74/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0032 - val_loss: 0.0051
# Epoch 75/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0047
# Epoch 76/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0029 - val_loss: 0.0048
# Epoch 77/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 78/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0030 - val_loss: 0.0044
# Epoch 79/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 80/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0031 - val_loss: 0.0051
# Epoch 81/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 82/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0044
# Epoch 83/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0031 - val_loss: 0.0048
# Epoch 84/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0029 - val_loss: 0.0046
# Epoch 85/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 86/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0030 - val_loss: 0.0050
# Epoch 87/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 88/100
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0030 - val_loss: 0.0053
# Epoch 89/100
# 91/91 [==============================] - 1s 9ms/step - loss: 0.0027 - val_loss: 0.0054
# Epoch 90/100
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0027 - val_loss: 0.0053
# Epoch 91/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 92/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0042
# Epoch 93/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0043
# Epoch 94/100
# 91/91 [==============================] - 1s 15ms/step - loss: 0.0028 - val_loss: 0.0050
# Epoch 95/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0030 - val_loss: 0.0042
# Epoch 96/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0026 - val_loss: 0.0044
# Epoch 97/100
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 98/100
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0026 - val_loss: 0.0052
# Epoch 99/100
# 91/91 [==============================] - 1s 8ms/step - loss: 0.0026 - val_loss: 0.0045
# Epoch 100/100
# 91/91 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0052

# %%
model = Sequential()
model.add(LSTM(64, input_shape=input_dimension, activation="relu"))
model.add(Dense(output_dimension))
model.compile(loss="mse", optimizer="adam") 
model.summary()
history = model.fit(Xtrain, Ytrain, batch_size=5, epochs=40, verbose = 0)
predictionsLSTM = model.predict(Xtest)

Predictionsinversed = scaler_y.inverse_transform(predictionsLSTM)
Ytestinversed = scaler_y.inverse_transform(Ytest)

axis = range(len(Xtest))
plt.subplot(1, 1, 1)
plt.title("GRU Multi-Output Prediction: OIL, GAS and WAT Rates")
plt.scatter(axis, Ytestinversed[:,1],  s=6, label="GAS_RATE test")
plt.plot(axis, Predictionsinversed[:,1], label="GAS_RATE pred")

plt.legend()
plt.show()
plt.subplot(2, 1, 1)
plt.scatter(axis, Ytestinversed[:,0],  s=6, label="OIL_RATE test")
plt.plot(axis, Predictionsinversed[:,0], label="OIL_RATE pred")
plt.legend()
plt.show()
plt.subplot(3, 1, 1)
plt.scatter(axis, Ytestinversed[:,2],  s=6, label="WAT_RATE test")
plt.plot(axis, Predictionsinversed[:,2], label="WAT_RATE pred")

plt.legend()
plt.show()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 64)                16896
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 17,091
# Trainable params: 17,091
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("Relative Absolute Error metric using LSTM model")

print("OIL_RATE RAE:%.4f" % rae(Ytestinversed[:,0], Predictionsinversed[:,0]))
print("GAS_RATE RAE:%.4f" % rae(Ytestinversed[:,1], Predictionsinversed[:,1])) 
print("WAT_RATE RAE:%.4f" % rae(Ytestinversed[:,2], Predictionsinversed[:,2]))

print('\n')
print("Relative Squared Error metric using LSTM model")

print("OIL_RATE RSE:%.4f" % rse(Ytestinversed[:,0], Predictionsinversed[:,0]))
print("GAS_RATE RSE:%.4f" % rse(Ytestinversed[:,1], Predictionsinversed[:,1])) 
print("WAT_RATE RSE:%.4f" % rse(Ytestinversed[:,2], Predictionsinversed[:,2]))
# Out:
# Relative Absolute Error metric using LSTM model
# OIL_RATE RAE:0.5595
# GAS_RATE RAE:0.5285
# WAT_RATE RAE:0.1670
#
#
# Relative Squared Error metric using LSTM model
# OIL_RATE RSE:0.3873
# GAS_RATE RSE:0.3645
# WAT_RATE RSE:0.1056

# %% [markdown]
# ## Conclusion:
#
# We can assume that scaling the data is a crucial step the data preprocessing. Both of the models give good results after scaling using MinMaxScaler() function. However, we can notice that GRU results are slightly better than LSTM model especially if we compare RAE metric.
#
# 1. Relative Absolute Error metric:
#
# LSTM model
#     - OIL_RATE RAE:0.5595
#     - GAS_RATE RAE:0.5285
#     - WAT_RATE RAE:0.1670
#
#
# GRU model
#     - OIL_RATE RAE:0.4654
#     - GAS_RATE RAE:0.4729
#     - WAT_RATE RAE:0.1730
#
#
#
#
# 2. Relative Squared Error metric:
#
# LSTM model
#     - OIL_RATE RSE:0.3873
#     - GAS_RATE RSE:0.3645
#     - WAT_RATE RSE:0.1056
#
# GRU model
#     - OIL_RATE RSE:0.2918
#     - GAS_RATE RSE:0.3242
#     - WAT_RATE RSE:0.1055
